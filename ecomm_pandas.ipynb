# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/E-Commerce - E-Commerce (1).csv")

# %%
df.head()
# Out:
#    Order_ID Product_Name     Category  Price  Quantity Customer_ID  Order_Date
# 0         1       Laptop  Electronics   1200         2        C101  01-01-2024
# 1         2   Headphones  Electronics     80         3        C102  02-01-2024
# 2         3        Chair    Furniture    150         1        C103  03-01-2024
# 3         4   Smartphone  Electronics    600         1        C104  04-01-2024
# 4         5         Desk    Furniture    200         2        C105  05-01-2024

# %%
df.tail()
# Out:
#     Order_ID Product_Name     Category  Price  Quantity Customer_ID  \
# 25        26        Watch  Accessories    120         1        C108
# 26        27       Camera  Electronics    750         1        C113
# 27        28        Jeans      Apparel     35         4        C113
# 28        29      Printer  Electronics    130         1        C105
# 29        30      Perfume       Beauty     30         3        C102
#
#     Order_Date
# 25  26-01-2024
# 26  27-01-2024
# 27  28-01-2024
# 28  29-01-2024
# 29  30-01-2024

# %%
df.shape
# Out:
# (30, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order_ID      30 non-null     int64
#  1   Product_Name  30 non-null     object
#  2   Category      30 non-null     object
#  3   Price         30 non-null     int64
#  4   Quantity      30 non-null     int64
#  5   Customer_ID   30 non-null     object
#  6   Order_Date    30 non-null     object
# dtypes: int64(3), object(4)
# memory usage: 1.8+ KB

# %%
df.describe()
# Out:
#         Order_ID        Price   Quantity
# count  30.000000    30.000000  30.000000
# mean   15.500000   200.833333   2.033333
# std     8.803408   277.134610   1.159171
# min     1.000000    15.000000   1.000000
# 25%     8.250000    41.250000   1.000000
# 50%    15.500000   110.000000   2.000000
# 75%    22.750000   195.000000   3.000000
# max    30.000000  1200.000000   5.000000

# %%
col=df.columns
col
# Out:
# Index(['Order_ID', 'Product_Name', 'Category', 'Price', 'Quantity',
#        'Customer_ID', 'Order_Date'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Order_ID        0
# Product_Name    0
# Category        0
# Price           0
# Quantity        0
# Customer_ID     0
# Order_Date      0
# dtype: int64

# %%
df['Category'].unique()
# Out:
# array(['Electronics', 'Furniture', 'Apparel', 'Books', 'Accessories',
#        'Beauty'], dtype=object)

# %%
df['Category'].nunique()
# Out:
# 6

# %%
df['Quantity'].sum()
# Out:
# np.int64(61)

# %%
df.groupby('Category')['Price'].mean().sort_values()
# Out:
# Category
# Books           17.500000
# Beauty          27.500000
# Apparel         37.500000
# Accessories     82.500000
# Furniture      196.666667
# Electronics    420.000000
# Name: Price, dtype: float64

# %%
df['Product_Price']=df['Price']/df['Quantity']

# %%
df.head()
# Out:
#    Order_ID Product_Name     Category  Price  Quantity Customer_ID  \
# 0         1       Laptop  Electronics   1200         2        C101
# 1         2   Headphones  Electronics     80         3        C102
# 2         3        Chair    Furniture    150         1        C103
# 3         4   Smartphone  Electronics    600         1        C104
# 4         5         Desk    Furniture    200         2        C105
#
#    Order_Date  Product_Price
# 0  01-01-2024     600.000000
# 1  02-01-2024      26.666667
# 2  03-01-2024     150.000000
# 3  04-01-2024     600.000000
# 4  05-01-2024     100.000000

# %%
df1=df[df['Product_Price']==df['Product_Price'].max()]
df1
# Out:
#     Order_ID Product_Name     Category  Price  Quantity Customer_ID  \
# 12        13       Camera  Electronics    800         1        C113
#
#     Order_Date  Product_Price
# 12  13-01-2024          800.0

# %%
df.iloc[[df['Price'].idxmax()]]
# Out:
#    Order_ID Product_Name     Category  Price  Quantity Customer_ID  \
# 0         1       Laptop  Electronics   1200         2        C101
#
#    Order_Date  Product_Price
# 0  01-01-2024          600.0

# %%
df['Total']=df['Price']*df['Quantity']
max_total_customer_id = df.groupby('Customer_ID')['Total'].sum().idxmax()
df[df['Customer_ID'] == max_total_customer_id]
# Out:
#     Order_ID Product_Name     Category  Price  Quantity Customer_ID  \
# 0          1       Laptop  Electronics   1200         2        C101
# 15        16      Perfume       Beauty     25         4        C101
# 19        20   Headphones  Electronics     70         3        C101
#
#     Order_Date  Product_Price  Total
# 0   01-01-2024     600.000000   2400
# 15  16-01-2024       6.250000    100
# 19  20-01-2024      23.333333    210

# %%
df['Total'].sum()
# Out:
# np.int64(8615)

# %%
df[df['Order_Date']=='05-01-2024']
# Out:
#    Order_ID Product_Name   Category  Price  Quantity Customer_ID  Order_Date  \
# 4         5         Desk  Furniture    200         2        C105  05-01-2024
#
#    Product_Price  Total
# 4          100.0    400

# %%
df2=df.groupby('Customer_ID')['Total'].sum().sort_values(ascending=False).head(3)
df2
#Print entie detail of these 3 cusr=t in df2
for i in df2.index:
  print(df[df['Customer_ID']==i])
# Out:
#     Order_ID Product_Name     Category  Price  Quantity Customer_ID  \
# 0          1       Laptop  Electronics   1200         2        C101
# 15        16      Perfume       Beauty     25         4        C101
# 19        20   Headphones  Electronics     70         3        C101
#
#     Order_Date  Product_Price  Total
# 0   01-01-2024     600.000000   2400
# 15  16-01-2024       6.250000    100
# 19  20-01-2024      23.333333    210
#     Order_ID Product_Name     Category  Price  Quantity Customer_ID  \
# 12        13       Camera  Electronics    800         1        C113
# 26        27       Camera  Electronics    750         1        C113
# 27        28        Jeans      Apparel     35         4        C113
#
#     Order_Date  Product_Price  Total
# 12  13-01-2024         800.00    800
# 26  27-01-2024         750.00    750
# 27  28-01-2024           8.75    140
#    Order_ID Product_Name     Category  Price  Quantity Customer_ID  \
# ...

# %%
df.groupby('Category')['Order_ID'].unique()
# Out:
# Category
# Accessories                        [11, 12, 18, 26]
# Apparel                      [6, 8, 14, 21, 24, 28]
# Beauty                                     [16, 30]
# Books                                       [9, 22]
# Electronics    [1, 2, 4, 7, 13, 15, 17, 20, 27, 29]
# Furniture                    [3, 5, 10, 19, 23, 25]
# Name: Order_ID, dtype: object

# %%
df['Category'].value_counts()
# Out:
# Category
# Electronics    10
# Furniture       6
# Apparel         6
# Accessories     4
# Books           2
# Beauty          2
# Name: count, dtype: int64

# %%
df.sort_values(by='Category')
# Out:
#     Order_ID Product_Name     Category  Price  Quantity Customer_ID  \
# 25        26        Watch  Accessories    120         1        C108
# 10        11        Watch  Accessories    100         1        C111
# 11        12     Backpack  Accessories     50         2        C112
# 17        18   Sunglasses  Accessories     60         2        C118
# 27        28        Jeans      Apparel     35         4        C113
# 23        24        Shoes      Apparel     45         2        C112
# 5          6        Shirt      Apparel     30         5        C106
# 7          8        Shoes      Apparel     50         2        C108
# 20        21        Shirt      Apparel     25         4        C110
# 13        14        Jeans      Apparel     40         3        C114
# 29        30      Perfume       Beauty     30         3        C102
# 15        16      Perfume       Beauty     25         4        C101
# 21        22         Book        Books     20         2        C105
# ...

# %%
df[df['Quantity']>3]
# Out:
#     Order_ID Product_Name Category  Price  Quantity Customer_ID  Order_Date  \
# 5          6        Shirt  Apparel     30         5        C106  06-01-2024
# 15        16      Perfume   Beauty     25         4        C101  16-01-2024
# 20        21        Shirt  Apparel     25         4        C110  21-01-2024
# 27        28        Jeans  Apparel     35         4        C113  28-01-2024
#
#     Product_Price  Total
# 5            6.00    150
# 15           6.25    100
# 20           6.25    100
# 27           8.75    140

# %%
df.groupby('Product_Name')['Quantity'].mean()
# Out:
# Product_Name
# Backpack      2.000000
# Book          2.500000
# Camera        1.000000
# Chair         1.000000
# Desk          1.333333
# Headphones    3.000000
# Jeans         3.500000
# Laptop        2.000000
# Perfume       3.500000
# Printer       1.000000
# Shirt         4.500000
# Shoes         2.000000
# Smartphone    1.000000
# Speaker       2.000000
# Sunglasses    2.000000
# Table         1.000000
# Tablet        1.000000
# Watch         1.000000
# Name: Quantity, dtype: float64

# %%
df.groupby('Product_Name')['Quantity'].sum().max()
# Out:
# 9

# %%
df['Product_Name'].value_counts()[df['Product_Name'].value_counts()>1]
# Out:
# Product_Name
# Desk          3
# Headphones    2
# Printer       2
# Chair         2
# Shirt         2
# Shoes         2
# Watch         2
# Book          2
# Jeans         2
# Camera        2
# Perfume       2
# Name: count, dtype: int64

# %%
df.groupby(['Category','Product_Name'])["Total"].sum()   #TOTAL COST PER PRODUCT IN EACH CATEGORY
# Out:
# Category     Product_Name
# Accessories  Backpack         100
#              Sunglasses       120
#              Watch            220
# Apparel      Jeans            260
#              Shirt            250
#              Shoes            190
# Beauty       Perfume          190
# Books        Book              85
# Electronics  Camera          1550
#              Headphones       450
#              Laptop          2400
#              Printer          280
#              Smartphone       600
#              Speaker          240
#              Tablet           300
# Furniture    Chair            330
#              Desk             800
#              Table            250
# Name: Total, dtype: int64

# %%
df.groupby(['Category'])["Total"].sum()
# Out:
# Category
# Accessories     440
# Apparel         700
# Beauty          190
# Books            85
# Electronics    5820
# Furniture      1380
# Name: Total, dtype: int64
